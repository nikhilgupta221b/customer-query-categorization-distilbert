# %%
# !pip install -q transformers datasets accelerate
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import pandas as pd
import numpy as np
import torch
import time
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments,
    pipeline,
    DataCollatorWithPadding,
    EvalPrediction
)
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# %%
# Configuration
WORD_THRESHOLD = 300  # Summarize texts longer than this many words
MIN_SUMMARY_LENGTH = 50  # Minimum summary length
MAX_SUMMARY_LENGTH = 200  # Maximum summary length
BATCH_SIZE_SUMMARY = 8  # Batch size for summarization
BATCH_SIZE_TRAINING = 16  # Batch size for training

# Model saving configuration
MODEL_SAVE_DIR = "./saved_ticket_classifier"
TOKENIZER_SAVE_DIR = os.path.join(MODEL_SAVE_DIR, "tokenizer")
MODEL_WEIGHTS_DIR = os.path.join(MODEL_SAVE_DIR, "model")
METADATA_FILE = os.path.join(MODEL_SAVE_DIR, "metadata.json")
LABEL_ENCODER_FILE = os.path.join(MODEL_SAVE_DIR, "label_encoder.pkl")

def create_save_directories():
    """Create directories for saving model components"""
    os.makedirs(MODEL_SAVE_DIR, exist_ok=True)
    os.makedirs(TOKENIZER_SAVE_DIR, exist_ok=True)
    os.makedirs(MODEL_WEIGHTS_DIR, exist_ok=True)
    print(f"Created save directories: {MODEL_SAVE_DIR}")

def save_model_components(model, tokenizer, label_encoder, training_config, results):
    """Save all model components needed for inference"""
    create_save_directories()

    print("Saving model components...")

    # Save the trained model
    model.save_pretrained(MODEL_WEIGHTS_DIR)
    print(f"✓ Model saved to: {MODEL_WEIGHTS_DIR}")

    # Save the tokenizer
    tokenizer.save_pretrained(TOKENIZER_SAVE_DIR)
    print(f"✓ Tokenizer saved to: {TOKENIZER_SAVE_DIR}")

    # Save label encoder
    with open(LABEL_ENCODER_FILE, 'wb') as f:
        pickle.dump(label_encoder, f)
    print(f"✓ Label encoder saved to: {LABEL_ENCODER_FILE}")

    # Save metadata and configuration
    metadata = {
        "model_name": "distilbert-base-uncased",
        "num_labels": len(label_encoder.classes_),
        "label_classes": label_encoder.classes_.tolist(),
        "max_length": 512,
        "word_threshold": WORD_THRESHOLD,
        "min_summary_length": MIN_SUMMARY_LENGTH,
        "max_summary_length": MAX_SUMMARY_LENGTH,
        "training_config": training_config,
        "results": results,
        "save_timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "preprocessing_params": {
            "summarization_model": "facebook/bart-large-cnn",
            "tokenizer_model": "distilbert-base-uncased"
        }
    }

    with open(METADATA_FILE, 'w') as f:
        json.dump(metadata, f, indent=2, default=str)
    print(f"✓ Metadata saved to: {METADATA_FILE}")

    print(f"\n✅ All model components saved successfully to: {MODEL_SAVE_DIR}")
    return MODEL_SAVE_DIR

# %%
def load_model_for_inference(model_dir=MODEL_SAVE_DIR):
    """
    Load all model components for inference
    Usage example after loading:
        model, tokenizer, label_encoder, metadata = load_model_for_inference()
    """
    print(f"Loading model components from: {model_dir}")

    # Load metadata
    with open(os.path.join(model_dir, "metadata.json"), 'r') as f:
        metadata = json.load(f)

    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained(os.path.join(model_dir, "tokenizer"))

    # Load model
    model = AutoModelForSequenceClassification.from_pretrained(os.path.join(model_dir, "model"))

    # Load label encoder
    with open(os.path.join(model_dir, "label_encoder.pkl"), 'rb') as f:
        label_encoder = pickle.load(f)

    print("✅ Model components loaded successfully!")
    print(f"Model: {metadata['model_name']}")
    print(f"Number of classes: {metadata['num_labels']}")
    print(f"Classes: {metadata['label_classes']}")

    return model, tokenizer, label_encoder, metadata

# %%
def predict_ticket_category(text, model, tokenizer, label_encoder, device='cpu', max_length=512):
    """
    Predict the category of a single ticket text
    """
    model.eval()
    model.to(device)

    # Tokenize input
    encoding = tokenizer(
        str(text),
        truncation=True,
        padding='max_length',
        max_length=max_length,
        return_tensors='pt'
    )

    # Move to device
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    # Make prediction
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
        predicted_class = torch.argmax(predictions, dim=-1).cpu().numpy()[0]
        confidence = torch.max(predictions).cpu().numpy()

    # Convert back to original label
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]

    return {
        'predicted_class': predicted_label,
        'confidence': float(confidence),
        'class_probabilities': {
            label_encoder.classes_[i]: float(predictions[0][i].cpu().numpy())
            for i in range(len(label_encoder.classes_))
        }
    }

# %%
# !pip install -q transformers datasets accelerate

import pandas as pd
import numpy as np
import torch
import time
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments,
    pipeline,
    DataCollatorWithPadding,
    EvalPrediction
)
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Configuration
WORD_THRESHOLD = 300  # Summarize texts longer than this many words
MIN_SUMMARY_LENGTH = 50  # Minimum summary length
MAX_SUMMARY_LENGTH = 200  # Maximum summary length
BATCH_SIZE_SUMMARY = 8  # Batch size for summarization
BATCH_SIZE_TRAINING = 16  # Batch size for training

# Model saving configuration
MODEL_SAVE_DIR = "./saved_ticket_classifier"
TOKENIZER_SAVE_DIR = os.path.join(MODEL_SAVE_DIR, "tokenizer")
MODEL_WEIGHTS_DIR = os.path.join(MODEL_SAVE_DIR, "model")
METADATA_FILE = os.path.join(MODEL_SAVE_DIR, "metadata.json")
LABEL_ENCODER_FILE = os.path.join(MODEL_SAVE_DIR, "label_encoder.pkl")

def create_save_directories():
    """Create directories for saving model components"""
    os.makedirs(MODEL_SAVE_DIR, exist_ok=True)
    os.makedirs(TOKENIZER_SAVE_DIR, exist_ok=True)
    os.makedirs(MODEL_WEIGHTS_DIR, exist_ok=True)
    print(f"Created save directories: {MODEL_SAVE_DIR}")

def save_model_components(model, tokenizer, label_encoder, training_config, results):
    """Save all model components needed for inference"""
    create_save_directories()

    print("Saving model components...")

    # Save the trained model
    model.save_pretrained(MODEL_WEIGHTS_DIR)
    print(f"✓ Model saved to: {MODEL_WEIGHTS_DIR}")

    # Save the tokenizer
    tokenizer.save_pretrained(TOKENIZER_SAVE_DIR)
    print(f"✓ Tokenizer saved to: {TOKENIZER_SAVE_DIR}")

    # Save label encoder
    with open(LABEL_ENCODER_FILE, 'wb') as f:
        pickle.dump(label_encoder, f)
    print(f"✓ Label encoder saved to: {LABEL_ENCODER_FILE}")

    # Save metadata and configuration
    metadata = {
        "model_name": "distilbert-base-uncased",
        "num_labels": len(label_encoder.classes_),
        "label_classes": label_encoder.classes_.tolist(),
        "max_length": 512,
        "word_threshold": WORD_THRESHOLD,
        "min_summary_length": MIN_SUMMARY_LENGTH,
        "max_summary_length": MAX_SUMMARY_LENGTH,
        "training_config": training_config,
        "results": results,
        "save_timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "preprocessing_params": {
            "summarization_model": "facebook/bart-large-cnn",
            "tokenizer_model": "distilbert-base-uncased"
        }
    }

    with open(METADATA_FILE, 'w') as f:
        json.dump(metadata, f, indent=2, default=str)
    print(f"✓ Metadata saved to: {METADATA_FILE}")

    print(f"\n✅ All model components saved successfully to: {MODEL_SAVE_DIR}")
    return MODEL_SAVE_DIR

def load_model_for_inference(model_dir=MODEL_SAVE_DIR):
    """
    Load all model components for inference
    Usage example after loading:
        model, tokenizer, label_encoder, metadata = load_model_for_inference()
    """
    print(f"Loading model components from: {model_dir}")

    # Load metadata
    with open(os.path.join(model_dir, "metadata.json"), 'r') as f:
        metadata = json.load(f)

    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained(os.path.join(model_dir, "tokenizer"))

    # Load model
    model = AutoModelForSequenceClassification.from_pretrained(os.path.join(model_dir, "model"))

    # Load label encoder
    with open(os.path.join(model_dir, "label_encoder.pkl"), 'rb') as f:
        label_encoder = pickle.load(f)

    print("✅ Model components loaded successfully!")
    print(f"Model: {metadata['model_name']}")
    print(f"Number of classes: {metadata['num_labels']}")
    print(f"Classes: {metadata['label_classes']}")

    return model, tokenizer, label_encoder, metadata

def predict_ticket_category(text, model, tokenizer, label_encoder, device='cpu', max_length=512):
    """
    Predict the category of a single ticket text
    """
    model.eval()
    model.to(device)

    # Tokenize input
    encoding = tokenizer(
        str(text),
        truncation=True,
        padding='max_length',
        max_length=max_length,
        return_tensors='pt'
    )

    # Move to device
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    # Make prediction
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
        predicted_class = torch.argmax(predictions, dim=-1).cpu().numpy()[0]
        confidence = torch.max(predictions).cpu().numpy()

    # Convert back to original label
    predicted_label = label_encoder.inverse_transform([predicted_class])[0]

    return {
        'predicted_class': predicted_label,
        'confidence': float(confidence),
        'class_probabilities': {
            label_encoder.classes_[i]: float(predictions[0][i].cpu().numpy())
            for i in range(len(label_encoder.classes_))
        }
    }

def count_words(text):
    """Count words in text"""
    if pd.isna(text) or text == "":
        return 0
    return len(str(text).split())
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
def summarize_texts(texts, summarizer, batch_size=BATCH_SIZE_SUMMARY):
    """
    Summarize texts in batches with proper error handling
    """
    summaries = []
    total_batches = len(texts) // batch_size + (1 if len(texts) % batch_size != 0 else 0)

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        print(f"Processing summarization batch {i//batch_size + 1}/{total_batches}")

        batch_summaries = []
        for text in batch_texts:
            try:
                if pd.isna(text) or text == "":
                    batch_summaries.append("")
                    continue

                # Check if text needs summarization
                word_count = count_words(text)
                if word_count <= WORD_THRESHOLD:
                    batch_summaries.append(str(text))
                    continue

                # Summarize long text
                summary = summarizer(
                    str(text),
                    max_length=MAX_SUMMARY_LENGTH,
                    min_length=MIN_SUMMARY_LENGTH,
                    do_sample=False,
                    truncation=True
                )[0]['summary_text']

                batch_summaries.append(summary)

            except Exception as e:
                print(f"Error summarizing text: {str(e)[:100]}...")
                # Fallback: use truncated original text
                words = str(text).split()[:WORD_THRESHOLD]
                batch_summaries.append(" ".join(words))

        summaries.extend(batch_summaries)

        # Clear cache periodically
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    return summaries

# %%
# Load and Prepare Dataset
print("Loading dataset...")
df = pd.read_csv("/kaggle/input/processes-tickets-1/processed_tickets.csv")

# Basic data cleaning
df = df.dropna(subset=['full_text', 'queue'])
df['full_text'] = df['full_text'].astype(str)
print(f"Dataset shape: {df.shape}")
print(f"Number of unique queues: {df['queue'].nunique()}")

# Analyze text lengths before summarization
df['word_count'] = df['full_text'].apply(count_words)
print(f"\nText length statistics:")
print(f"Mean words: {df['word_count'].mean():.1f}")
print(f"Median words: {df['word_count'].median():.1f}")
print(f"Max words: {df['word_count'].max()}")
print(f"Texts longer than {WORD_THRESHOLD} words: {(df['word_count'] > WORD_THRESHOLD).sum()}")
# Out:
# Loading dataset...
# Dataset shape: (11923, 7)
# Number of unique queues: 5
#
# Text length statistics:
# Mean words: 62.7
# Median words: 58.0
# Max words: 276
# Texts longer than 300 words: 0

# %%
# Initialize summarization pipeline
print("\nInitializing summarization model...")
device = 0 if torch.cuda.is_available() else -1
try:
    summarizer = pipeline(
        "summarization",
        model="facebook/bart-large-cnn",
        device=device,
        torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
    )
    print("Summarization model loaded successfully")
except Exception as e:
    print(f"Error loading BART model, falling back to simpler approach: {e}")
    # Fallback: simple truncation
    def simple_summarizer(text):
        words = str(text).split()
        if len(words) <= WORD_THRESHOLD:
            return text
        return " ".join(words[:WORD_THRESHOLD])

    summarizer = None
# Out:
# Initializing summarization model...
# Device set to use cuda:0
# Summarization model loaded successfully

# %%
# Summarize texts
print("\nStarting text summarization...")
start_time = time.time()
if summarizer is not None:
    # Use BART for summarization
    texts_to_process = df['full_text'].tolist()
    summarized_texts = summarize_texts(texts_to_process, summarizer)
    df['summarized_text'] = summarized_texts
else:
    # Fallback to simple truncation
    df['summarized_text'] = df['full_text'].apply(simple_summarizer)
summarization_time = time.time() - start_time
print(f"Summarization completed in {summarization_time:.2f} seconds")

# Clear summarization model from memory
if summarizer is not None:
    del summarizer
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# Starting text summarization...
# Processing summarization batch 1/1491
# Processing summarization batch 2/1491
# Processing summarization batch 3/1491
# Processing summarization batch 4/1491
# Processing summarization batch 5/1491
# Processing summarization batch 6/1491
# Processing summarization batch 7/1491
# Processing summarization batch 8/1491
# Processing summarization batch 9/1491
# Processing summarization batch 10/1491
# Processing summarization batch 11/1491
# Processing summarization batch 12/1491
# Processing summarization batch 13/1491
# Processing summarization batch 14/1491
# Processing summarization batch 15/1491
# Processing summarization batch 16/1491
# Processing summarization batch 17/1491
# Processing summarization batch 18/1491
# Processing summarization batch 19/1491
# Processing summarization batch 20/1491
# Processing summarization batch 21/1491
# Processing summarization batch 22/1491
# Processing summarization batch 23/1491
# Processing summarization batch 24/1491
# Processing summarization batch 25/1491
# Processing summarization batch 26/1491
# Processing summarization batch 27/1491
# Processing summarization batch 28/1491
# Processing summarization batch 29/1491
# Processing summarization batch 30/1491
# Processing summarization batch 31/1491
# Processing summarization batch 32/1491
# Processing summarization batch 33/1491
# Processing summarization batch 34/1491
# Processing summarization batch 35/1491
# Processing summarization batch 36/1491
# Processing summarization batch 37/1491
# Processing summarization batch 38/1491
# Processing summarization batch 39/1491
# Processing summarization batch 40/1491
# Processing summarization batch 41/1491
# Processing summarization batch 42/1491
# Processing summarization batch 43/1491
# Processing summarization batch 44/1491
# Processing summarization batch 45/1491
# Processing summarization batch 46/1491
# Processing summarization batch 47/1491
# Processing summarization batch 48/1491
# Processing summarization batch 49/1491
# Processing summarization batch 50/1491
# Processing summarization batch 51/1491
# Processing summarization batch 52/1491
# Processing summarization batch 53/1491
# Processing summarization batch 54/1491
# Processing summarization batch 55/1491
# Processing summarization batch 56/1491
# Processing summarization batch 57/1491
# Processing summarization batch 58/1491
# Processing summarization batch 59/1491
# Processing summarization batch 60/1491
# Processing summarization batch 61/1491
# Processing summarization batch 62/1491
# Processing summarization batch 63/1491
# Processing summarization batch 64/1491
# Processing summarization batch 65/1491
# Processing summarization batch 66/1491
# Processing summarization batch 67/1491
# Processing summarization batch 68/1491
# Processing summarization batch 69/1491
# Processing summarization batch 70/1491
# Processing summarization batch 71/1491
# Processing summarization batch 72/1491
# Processing summarization batch 73/1491
# Processing summarization batch 74/1491
# Processing summarization batch 75/1491
# Processing summarization batch 76/1491
# Processing summarization batch 77/1491
# Processing summarization batch 78/1491
# Processing summarization batch 79/1491
# Processing summarization batch 80/1491
# Processing summarization batch 81/1491
# Processing summarization batch 82/1491
# Processing summarization batch 83/1491
# Processing summarization batch 84/1491
# Processing summarization batch 85/1491
# Processing summarization batch 86/1491
# Processing summarization batch 87/1491
# Processing summarization batch 88/1491
# Processing summarization batch 89/1491
# Processing summarization batch 90/1491
# Processing summarization batch 91/1491
# Processing summarization batch 92/1491
# Processing summarization batch 93/1491
# Processing summarization batch 94/1491
# Processing summarization batch 95/1491
# Processing summarization batch 96/1491
# Processing summarization batch 97/1491
# Processing summarization batch 98/1491
# Processing summarization batch 99/1491
# Processing summarization batch 100/1491
# Processing summarization batch 101/1491
# Processing summarization batch 102/1491
# Processing summarization batch 103/1491
# Processing summarization batch 104/1491
# Processing summarization batch 105/1491
# Processing summarization batch 106/1491
# Processing summarization batch 107/1491
# Processing summarization batch 108/1491
# Processing summarization batch 109/1491
# Processing summarization batch 110/1491
# Processing summarization batch 111/1491
# Processing summarization batch 112/1491
# Processing summarization batch 113/1491
# Processing summarization batch 114/1491
# Processing summarization batch 115/1491
# Processing summarization batch 116/1491
# Processing summarization batch 117/1491
# Processing summarization batch 118/1491
# Processing summarization batch 119/1491
# Processing summarization batch 120/1491
# Processing summarization batch 121/1491
# Processing summarization batch 122/1491
# Processing summarization batch 123/1491
# Processing summarization batch 124/1491
# Processing summarization batch 125/1491
# Processing summarization batch 126/1491
# Processing summarization batch 127/1491
# Processing summarization batch 128/1491
# Processing summarization batch 129/1491
# Processing summarization batch 130/1491
# Processing summarization batch 131/1491
# Processing summarization batch 132/1491
# Processing summarization batch 133/1491
# Processing summarization batch 134/1491
# Processing summarization batch 135/1491
# Processing summarization batch 136/1491
# Processing summarization batch 137/1491
# Processing summarization batch 138/1491
# Processing summarization batch 139/1491
# Processing summarization batch 140/1491
# Processing summarization batch 141/1491
# Processing summarization batch 142/1491
# Processing summarization batch 143/1491
# Processing summarization batch 144/1491
# Processing summarization batch 145/1491
# Processing summarization batch 146/1491
# Processing summarization batch 147/1491
# Processing summarization batch 148/1491
# Processing summarization batch 149/1491
# Processing summarization batch 150/1491
# Processing summarization batch 151/1491
# Processing summarization batch 152/1491
# Processing summarization batch 153/1491
# Processing summarization batch 154/1491
# Processing summarization batch 155/1491
# Processing summarization batch 156/1491
# Processing summarization batch 157/1491
# Processing summarization batch 158/1491
# Processing summarization batch 159/1491
# Processing summarization batch 160/1491
# Processing summarization batch 161/1491
# Processing summarization batch 162/1491
# Processing summarization batch 163/1491
# Processing summarization batch 164/1491
# Processing summarization batch 165/1491
# Processing summarization batch 166/1491
# Processing summarization batch 167/1491
# Processing summarization batch 168/1491
# Processing summarization batch 169/1491
# Processing summarization batch 170/1491
# Processing summarization batch 171/1491
# Processing summarization batch 172/1491
# Processing summarization batch 173/1491
# Processing summarization batch 174/1491
# Processing summarization batch 175/1491
# Processing summarization batch 176/1491
# Processing summarization batch 177/1491
# Processing summarization batch 178/1491
# Processing summarization batch 179/1491
# Processing summarization batch 180/1491
# Processing summarization batch 181/1491
# Processing summarization batch 182/1491
# Processing summarization batch 183/1491
# Processing summarization batch 184/1491
# Processing summarization batch 185/1491
# Processing summarization batch 186/1491
# Processing summarization batch 187/1491
# Processing summarization batch 188/1491
# Processing summarization batch 189/1491
# Processing summarization batch 190/1491
# Processing summarization batch 191/1491
# Processing summarization batch 192/1491
# Processing summarization batch 193/1491
# Processing summarization batch 194/1491
# Processing summarization batch 195/1491
# Processing summarization batch 196/1491
# Processing summarization batch 197/1491
# Processing summarization batch 198/1491
# Processing summarization batch 199/1491
# Processing summarization batch 200/1491
# Processing summarization batch 201/1491
# Processing summarization batch 202/1491
# Processing summarization batch 203/1491
# Processing summarization batch 204/1491
# Processing summarization batch 205/1491
# Processing summarization batch 206/1491
# Processing summarization batch 207/1491
# Processing summarization batch 208/1491
# Processing summarization batch 209/1491
# Processing summarization batch 210/1491
# Processing summarization batch 211/1491
# Processing summarization batch 212/1491
# Processing summarization batch 213/1491
# Processing summarization batch 214/1491
# Processing summarization batch 215/1491
# Processing summarization batch 216/1491
# Processing summarization batch 217/1491
# Processing summarization batch 218/1491
# Processing summarization batch 219/1491
# Processing summarization batch 220/1491
# Processing summarization batch 221/1491
# Processing summarization batch 222/1491
# Processing summarization batch 223/1491
# Processing summarization batch 224/1491
# Processing summarization batch 225/1491
# Processing summarization batch 226/1491
# Processing summarization batch 227/1491
# Processing summarization batch 228/1491
# Processing summarization batch 229/1491
# Processing summarization batch 230/1491
# Processing summarization batch 231/1491
# Processing summarization batch 232/1491
# Processing summarization batch 233/1491
# Processing summarization batch 234/1491
# Processing summarization batch 235/1491
# Processing summarization batch 236/1491
# Processing summarization batch 237/1491
# Processing summarization batch 238/1491
# Processing summarization batch 239/1491
# Processing summarization batch 240/1491
# Processing summarization batch 241/1491
# Processing summarization batch 242/1491
# Processing summarization batch 243/1491
# Processing summarization batch 244/1491
# Processing summarization batch 245/1491
# Processing summarization batch 246/1491
# Processing summarization batch 247/1491
# Processing summarization batch 248/1491
# Processing summarization batch 249/1491
# Processing summarization batch 250/1491
# Processing summarization batch 251/1491
# Processing summarization batch 252/1491
# Processing summarization batch 253/1491
# Processing summarization batch 254/1491
# Processing summarization batch 255/1491
# Processing summarization batch 256/1491
# Processing summarization batch 257/1491
# Processing summarization batch 258/1491
# Processing summarization batch 259/1491
# Processing summarization batch 260/1491
# Processing summarization batch 261/1491
# Processing summarization batch 262/1491
# Processing summarization batch 263/1491
# Processing summarization batch 264/1491
# Processing summarization batch 265/1491
# Processing summarization batch 266/1491
# Processing summarization batch 267/1491
# Processing summarization batch 268/1491
# Processing summarization batch 269/1491
# Processing summarization batch 270/1491
# Processing summarization batch 271/1491
# Processing summarization batch 272/1491
# Processing summarization batch 273/1491
# Processing summarization batch 274/1491
# Processing summarization batch 275/1491
# Processing summarization batch 276/1491
# Processing summarization batch 277/1491
# Processing summarization batch 278/1491
# Processing summarization batch 279/1491
# Processing summarization batch 280/1491
# Processing summarization batch 281/1491
# Processing summarization batch 282/1491
# Processing summarization batch 283/1491
# Processing summarization batch 284/1491
# Processing summarization batch 285/1491
# Processing summarization batch 286/1491
# Processing summarization batch 287/1491
# Processing summarization batch 288/1491
# Processing summarization batch 289/1491
# Processing summarization batch 290/1491
# Processing summarization batch 291/1491
# Processing summarization batch 292/1491
# Processing summarization batch 293/1491
# Processing summarization batch 294/1491
# Processing summarization batch 295/1491
# Processing summarization batch 296/1491
# Processing summarization batch 297/1491
# Processing summarization batch 298/1491
# Processing summarization batch 299/1491
# Processing summarization batch 300/1491
# Processing summarization batch 301/1491
# Processing summarization batch 302/1491
# Processing summarization batch 303/1491
# Processing summarization batch 304/1491
# Processing summarization batch 305/1491
# Processing summarization batch 306/1491
# Processing summarization batch 307/1491
# Processing summarization batch 308/1491
# Processing summarization batch 309/1491
# Processing summarization batch 310/1491
# Processing summarization batch 311/1491
# Processing summarization batch 312/1491
# Processing summarization batch 313/1491
# Processing summarization batch 314/1491
# Processing summarization batch 315/1491
# Processing summarization batch 316/1491
# Processing summarization batch 317/1491
# Processing summarization batch 318/1491
# Processing summarization batch 319/1491
# Processing summarization batch 320/1491
# Processing summarization batch 321/1491
# Processing summarization batch 322/1491
# Processing summarization batch 323/1491
# Processing summarization batch 324/1491
# Processing summarization batch 325/1491
# Processing summarization batch 326/1491
# Processing summarization batch 327/1491
# Processing summarization batch 328/1491
# Processing summarization batch 329/1491
# Processing summarization batch 330/1491
# Processing summarization batch 331/1491
# Processing summarization batch 332/1491
# Processing summarization batch 333/1491
# Processing summarization batch 334/1491
# Processing summarization batch 335/1491
# Processing summarization batch 336/1491
# Processing summarization batch 337/1491
# Processing summarization batch 338/1491
# Processing summarization batch 339/1491
# Processing summarization batch 340/1491
# Processing summarization batch 341/1491
# Processing summarization batch 342/1491
# Processing summarization batch 343/1491
# Processing summarization batch 344/1491
# Processing summarization batch 345/1491
# Processing summarization batch 346/1491
# Processing summarization batch 347/1491
# Processing summarization batch 348/1491
# Processing summarization batch 349/1491
# Processing summarization batch 350/1491
# Processing summarization batch 351/1491
# Processing summarization batch 352/1491
# Processing summarization batch 353/1491
# Processing summarization batch 354/1491
# Processing summarization batch 355/1491
# Processing summarization batch 356/1491
# Processing summarization batch 357/1491
# Processing summarization batch 358/1491
# Processing summarization batch 359/1491
# Processing summarization batch 360/1491
# Processing summarization batch 361/1491
# Processing summarization batch 362/1491
# Processing summarization batch 363/1491
# Processing summarization batch 364/1491
# Processing summarization batch 365/1491
# Processing summarization batch 366/1491
# Processing summarization batch 367/1491
# Processing summarization batch 368/1491
# Processing summarization batch 369/1491
# Processing summarization batch 370/1491
# Processing summarization batch 371/1491
# Processing summarization batch 372/1491
# Processing summarization batch 373/1491
# Processing summarization batch 374/1491
# Processing summarization batch 375/1491
# Processing summarization batch 376/1491
# Processing summarization batch 377/1491
# Processing summarization batch 378/1491
# Processing summarization batch 379/1491
# Processing summarization batch 380/1491
# Processing summarization batch 381/1491
# Processing summarization batch 382/1491
# Processing summarization batch 383/1491
# Processing summarization batch 384/1491
# Processing summarization batch 385/1491
# Processing summarization batch 386/1491
# Processing summarization batch 387/1491
# Processing summarization batch 388/1491
# Processing summarization batch 389/1491
# Processing summarization batch 390/1491
# Processing summarization batch 391/1491
# Processing summarization batch 392/1491
# Processing summarization batch 393/1491
# Processing summarization batch 394/1491
# Processing summarization batch 395/1491
# Processing summarization batch 396/1491
# Processing summarization batch 397/1491
# Processing summarization batch 398/1491
# Processing summarization batch 399/1491
# Processing summarization batch 400/1491
# Processing summarization batch 401/1491
# Processing summarization batch 402/1491
# Processing summarization batch 403/1491
# Processing summarization batch 404/1491
# Processing summarization batch 405/1491
# Processing summarization batch 406/1491
# Processing summarization batch 407/1491
# Processing summarization batch 408/1491
# Processing summarization batch 409/1491
# Processing summarization batch 410/1491
# Processing summarization batch 411/1491
# Processing summarization batch 412/1491
# Processing summarization batch 413/1491
# Processing summarization batch 414/1491
# Processing summarization batch 415/1491
# Processing summarization batch 416/1491
# Processing summarization batch 417/1491
# Processing summarization batch 418/1491
# Processing summarization batch 419/1491
# Processing summarization batch 420/1491
# Processing summarization batch 421/1491
# Processing summarization batch 422/1491
# Processing summarization batch 423/1491
# Processing summarization batch 424/1491
# Processing summarization batch 425/1491
# Processing summarization batch 426/1491
# Processing summarization batch 427/1491
# Processing summarization batch 428/1491
# Processing summarization batch 429/1491
# Processing summarization batch 430/1491
# Processing summarization batch 431/1491
# Processing summarization batch 432/1491
# Processing summarization batch 433/1491
# Processing summarization batch 434/1491
# Processing summarization batch 435/1491
# Processing summarization batch 436/1491
# Processing summarization batch 437/1491
# Processing summarization batch 438/1491
# Processing summarization batch 439/1491
# Processing summarization batch 440/1491
# Processing summarization batch 441/1491
# Processing summarization batch 442/1491
# Processing summarization batch 443/1491
# Processing summarization batch 444/1491
# Processing summarization batch 445/1491
# Processing summarization batch 446/1491
# Processing summarization batch 447/1491
# Processing summarization batch 448/1491
# Processing summarization batch 449/1491
# Processing summarization batch 450/1491
# Processing summarization batch 451/1491
# Processing summarization batch 452/1491
# Processing summarization batch 453/1491
# Processing summarization batch 454/1491
# Processing summarization batch 455/1491
# Processing summarization batch 456/1491
# Processing summarization batch 457/1491
# Processing summarization batch 458/1491
# Processing summarization batch 459/1491
# Processing summarization batch 460/1491
# Processing summarization batch 461/1491
# Processing summarization batch 462/1491
# Processing summarization batch 463/1491
# Processing summarization batch 464/1491
# Processing summarization batch 465/1491
# Processing summarization batch 466/1491
# Processing summarization batch 467/1491
# Processing summarization batch 468/1491
# Processing summarization batch 469/1491
# Processing summarization batch 470/1491
# Processing summarization batch 471/1491
# Processing summarization batch 472/1491
# Processing summarization batch 473/1491
# Processing summarization batch 474/1491
# Processing summarization batch 475/1491
# Processing summarization batch 476/1491
# Processing summarization batch 477/1491
# Processing summarization batch 478/1491
# Processing summarization batch 479/1491
# Processing summarization batch 480/1491
# Processing summarization batch 481/1491
# Processing summarization batch 482/1491
# Processing summarization batch 483/1491
# Processing summarization batch 484/1491
# Processing summarization batch 485/1491
# Processing summarization batch 486/1491
# Processing summarization batch 487/1491
# Processing summarization batch 488/1491
# Processing summarization batch 489/1491
# Processing summarization batch 490/1491
# Processing summarization batch 491/1491
# Processing summarization batch 492/1491
# Processing summarization batch 493/1491
# Processing summarization batch 494/1491
# Processing summarization batch 495/1491
# Processing summarization batch 496/1491
# Processing summarization batch 497/1491
# Processing summarization batch 498/1491
# Processing summarization batch 499/1491
# Processing summarization batch 500/1491
# Processing summarization batch 501/1491
# Processing summarization batch 502/1491
# Processing summarization batch 503/1491
# Processing summarization batch 504/1491
# Processing summarization batch 505/1491
# Processing summarization batch 506/1491
# Processing summarization batch 507/1491
# Processing summarization batch 508/1491
# Processing summarization batch 509/1491
# Processing summarization batch 510/1491
# Processing summarization batch 511/1491
# Processing summarization batch 512/1491
# Processing summarization batch 513/1491
# Processing summarization batch 514/1491
# Processing summarization batch 515/1491
# Processing summarization batch 516/1491
# Processing summarization batch 517/1491
# Processing summarization batch 518/1491
# Processing summarization batch 519/1491
# Processing summarization batch 520/1491
# Processing summarization batch 521/1491
# Processing summarization batch 522/1491
# Processing summarization batch 523/1491
# Processing summarization batch 524/1491
# Processing summarization batch 525/1491
# Processing summarization batch 526/1491
# Processing summarization batch 527/1491
# Processing summarization batch 528/1491
# Processing summarization batch 529/1491
# Processing summarization batch 530/1491
# Processing summarization batch 531/1491
# Processing summarization batch 532/1491
# Processing summarization batch 533/1491
# Processing summarization batch 534/1491
# Processing summarization batch 535/1491
# Processing summarization batch 536/1491
# Processing summarization batch 537/1491
# Processing summarization batch 538/1491
# Processing summarization batch 539/1491
# Processing summarization batch 540/1491
# Processing summarization batch 541/1491
# Processing summarization batch 542/1491
# Processing summarization batch 543/1491
# Processing summarization batch 544/1491
# Processing summarization batch 545/1491
# Processing summarization batch 546/1491
# Processing summarization batch 547/1491
# Processing summarization batch 548/1491
# Processing summarization batch 549/1491
# Processing summarization batch 550/1491
# Processing summarization batch 551/1491
# Processing summarization batch 552/1491
# Processing summarization batch 553/1491
# Processing summarization batch 554/1491
# Processing summarization batch 555/1491
# Processing summarization batch 556/1491
# Processing summarization batch 557/1491
# Processing summarization batch 558/1491
# Processing summarization batch 559/1491
# Processing summarization batch 560/1491
# Processing summarization batch 561/1491
# Processing summarization batch 562/1491
# Processing summarization batch 563/1491
# Processing summarization batch 564/1491
# Processing summarization batch 565/1491
# Processing summarization batch 566/1491
# Processing summarization batch 567/1491
# Processing summarization batch 568/1491
# Processing summarization batch 569/1491
# Processing summarization batch 570/1491
# Processing summarization batch 571/1491
# Processing summarization batch 572/1491
# Processing summarization batch 573/1491
# Processing summarization batch 574/1491
# Processing summarization batch 575/1491
# Processing summarization batch 576/1491
# Processing summarization batch 577/1491
# Processing summarization batch 578/1491
# Processing summarization batch 579/1491
# Processing summarization batch 580/1491
# Processing summarization batch 581/1491
# Processing summarization batch 582/1491
# Processing summarization batch 583/1491
# Processing summarization batch 584/1491
# Processing summarization batch 585/1491
# Processing summarization batch 586/1491
# Processing summarization batch 587/1491
# Processing summarization batch 588/1491
# Processing summarization batch 589/1491
# Processing summarization batch 590/1491
# Processing summarization batch 591/1491
# Processing summarization batch 592/1491
# Processing summarization batch 593/1491
# Processing summarization batch 594/1491
# Processing summarization batch 595/1491
# Processing summarization batch 596/1491
# Processing summarization batch 597/1491
# Processing summarization batch 598/1491
# Processing summarization batch 599/1491
# Processing summarization batch 600/1491
# Processing summarization batch 601/1491
# Processing summarization batch 602/1491
# Processing summarization batch 603/1491
# Processing summarization batch 604/1491
# Processing summarization batch 605/1491
# Processing summarization batch 606/1491
# Processing summarization batch 607/1491
# Processing summarization batch 608/1491
# Processing summarization batch 609/1491
# Processing summarization batch 610/1491
# Processing summarization batch 611/1491
# Processing summarization batch 612/1491
# Processing summarization batch 613/1491
# Processing summarization batch 614/1491
# Processing summarization batch 615/1491
# Processing summarization batch 616/1491
# Processing summarization batch 617/1491
# Processing summarization batch 618/1491
# Processing summarization batch 619/1491
# Processing summarization batch 620/1491
# Processing summarization batch 621/1491
# Processing summarization batch 622/1491
# Processing summarization batch 623/1491
# Processing summarization batch 624/1491
# Processing summarization batch 625/1491
# Processing summarization batch 626/1491
# Processing summarization batch 627/1491
# Processing summarization batch 628/1491
# Processing summarization batch 629/1491
# Processing summarization batch 630/1491
# Processing summarization batch 631/1491
# Processing summarization batch 632/1491
# Processing summarization batch 633/1491
# Processing summarization batch 634/1491
# Processing summarization batch 635/1491
# Processing summarization batch 636/1491
# Processing summarization batch 637/1491
# Processing summarization batch 638/1491
# Processing summarization batch 639/1491
# Processing summarization batch 640/1491
# Processing summarization batch 641/1491
# Processing summarization batch 642/1491
# Processing summarization batch 643/1491
# Processing summarization batch 644/1491
# Processing summarization batch 645/1491
# Processing summarization batch 646/1491
# Processing summarization batch 647/1491
# Processing summarization batch 648/1491
# Processing summarization batch 649/1491
# Processing summarization batch 650/1491
# Processing summarization batch 651/1491
# Processing summarization batch 652/1491
# Processing summarization batch 653/1491
# Processing summarization batch 654/1491
# Processing summarization batch 655/1491
# Processing summarization batch 656/1491
# Processing summarization batch 657/1491
# Processing summarization batch 658/1491
# Processing summarization batch 659/1491
# Processing summarization batch 660/1491
# Processing summarization batch 661/1491
# Processing summarization batch 662/1491
# Processing summarization batch 663/1491
# Processing summarization batch 664/1491
# Processing summarization batch 665/1491
# Processing summarization batch 666/1491
# Processing summarization batch 667/1491
# Processing summarization batch 668/1491
# Processing summarization batch 669/1491
# Processing summarization batch 670/1491
# Processing summarization batch 671/1491
# Processing summarization batch 672/1491
# Processing summarization batch 673/1491
# Processing summarization batch 674/1491
# Processing summarization batch 675/1491
# Processing summarization batch 676/1491
# Processing summarization batch 677/1491
# Processing summarization batch 678/1491
# Processing summarization batch 679/1491
# Processing summarization batch 680/1491
# Processing summarization batch 681/1491
# Processing summarization batch 682/1491
# Processing summarization batch 683/1491
# Processing summarization batch 684/1491
# Processing summarization batch 685/1491
# Processing summarization batch 686/1491
# Processing summarization batch 687/1491
# Processing summarization batch 688/1491
# Processing summarization batch 689/1491
# Processing summarization batch 690/1491
# Processing summarization batch 691/1491
# Processing summarization batch 692/1491
# Processing summarization batch 693/1491
# Processing summarization batch 694/1491
# Processing summarization batch 695/1491
# Processing summarization batch 696/1491
# Processing summarization batch 697/1491
# Processing summarization batch 698/1491
# Processing summarization batch 699/1491
# Processing summarization batch 700/1491
# Processing summarization batch 701/1491
# Processing summarization batch 702/1491
# Processing summarization batch 703/1491
# Processing summarization batch 704/1491
# Processing summarization batch 705/1491
# Processing summarization batch 706/1491
# Processing summarization batch 707/1491
# Processing summarization batch 708/1491
# Processing summarization batch 709/1491
# Processing summarization batch 710/1491
# Processing summarization batch 711/1491
# Processing summarization batch 712/1491
# Processing summarization batch 713/1491
# Processing summarization batch 714/1491
# Processing summarization batch 715/1491
# Processing summarization batch 716/1491
# Processing summarization batch 717/1491
# Processing summarization batch 718/1491
# Processing summarization batch 719/1491
# Processing summarization batch 720/1491
# Processing summarization batch 721/1491
# Processing summarization batch 722/1491
# Processing summarization batch 723/1491
# Processing summarization batch 724/1491
# Processing summarization batch 725/1491
# Processing summarization batch 726/1491
# Processing summarization batch 727/1491
# Processing summarization batch 728/1491
# Processing summarization batch 729/1491
# Processing summarization batch 730/1491
# Processing summarization batch 731/1491
# Processing summarization batch 732/1491
# Processing summarization batch 733/1491
# Processing summarization batch 734/1491
# Processing summarization batch 735/1491
# Processing summarization batch 736/1491
# Processing summarization batch 737/1491
# Processing summarization batch 738/1491
# Processing summarization batch 739/1491
# Processing summarization batch 740/1491
# Processing summarization batch 741/1491
# Processing summarization batch 742/1491
# Processing summarization batch 743/1491
# Processing summarization batch 744/1491
# Processing summarization batch 745/1491
# Processing summarization batch 746/1491
# Processing summarization batch 747/1491
# Processing summarization batch 748/1491
# Processing summarization batch 749/1491
# Processing summarization batch 750/1491
# Processing summarization batch 751/1491
# Processing summarization batch 752/1491
# Processing summarization batch 753/1491
# Processing summarization batch 754/1491
# Processing summarization batch 755/1491
# Processing summarization batch 756/1491
# Processing summarization batch 757/1491
# Processing summarization batch 758/1491
# Processing summarization batch 759/1491
# Processing summarization batch 760/1491
# Processing summarization batch 761/1491
# Processing summarization batch 762/1491
# Processing summarization batch 763/1491
# Processing summarization batch 764/1491
# Processing summarization batch 765/1491
# Processing summarization batch 766/1491
# Processing summarization batch 767/1491
# Processing summarization batch 768/1491
# Processing summarization batch 769/1491
# Processing summarization batch 770/1491
# Processing summarization batch 771/1491
# Processing summarization batch 772/1491
# Processing summarization batch 773/1491
# Processing summarization batch 774/1491
# Processing summarization batch 775/1491
# Processing summarization batch 776/1491
# Processing summarization batch 777/1491
# Processing summarization batch 778/1491
# Processing summarization batch 779/1491
# Processing summarization batch 780/1491
# Processing summarization batch 781/1491
# Processing summarization batch 782/1491
# Processing summarization batch 783/1491
# Processing summarization batch 784/1491
# Processing summarization batch 785/1491
# Processing summarization batch 786/1491
# Processing summarization batch 787/1491
# Processing summarization batch 788/1491
# Processing summarization batch 789/1491
# Processing summarization batch 790/1491
# Processing summarization batch 791/1491
# Processing summarization batch 792/1491
# Processing summarization batch 793/1491
# Processing summarization batch 794/1491
# Processing summarization batch 795/1491
# Processing summarization batch 796/1491
# Processing summarization batch 797/1491
# Processing summarization batch 798/1491
# Processing summarization batch 799/1491
# Processing summarization batch 800/1491
# Processing summarization batch 801/1491
# Processing summarization batch 802/1491
# Processing summarization batch 803/1491
# Processing summarization batch 804/1491
# Processing summarization batch 805/1491
# Processing summarization batch 806/1491
# Processing summarization batch 807/1491
# Processing summarization batch 808/1491
# Processing summarization batch 809/1491
# Processing summarization batch 810/1491
# Processing summarization batch 811/1491
# Processing summarization batch 812/1491
# Processing summarization batch 813/1491
# Processing summarization batch 814/1491
# Processing summarization batch 815/1491
# Processing summarization batch 816/1491
# Processing summarization batch 817/1491
# Processing summarization batch 818/1491
# Processing summarization batch 819/1491
# Processing summarization batch 820/1491
# Processing summarization batch 821/1491
# Processing summarization batch 822/1491
# Processing summarization batch 823/1491
# Processing summarization batch 824/1491
# Processing summarization batch 825/1491
# Processing summarization batch 826/1491
# Processing summarization batch 827/1491
# Processing summarization batch 828/1491
# Processing summarization batch 829/1491
# Processing summarization batch 830/1491
# Processing summarization batch 831/1491
# Processing summarization batch 832/1491
# Processing summarization batch 833/1491
# Processing summarization batch 834/1491
# Processing summarization batch 835/1491
# Processing summarization batch 836/1491
# Processing summarization batch 837/1491
# Processing summarization batch 838/1491
# Processing summarization batch 839/1491
# Processing summarization batch 840/1491
# Processing summarization batch 841/1491
# Processing summarization batch 842/1491
# Processing summarization batch 843/1491
# Processing summarization batch 844/1491
# Processing summarization batch 845/1491
# Processing summarization batch 846/1491
# Processing summarization batch 847/1491
# Processing summarization batch 848/1491
# Processing summarization batch 849/1491
# Processing summarization batch 850/1491
# Processing summarization batch 851/1491
# Processing summarization batch 852/1491
# Processing summarization batch 853/1491
# Processing summarization batch 854/1491
# Processing summarization batch 855/1491
# Processing summarization batch 856/1491
# Processing summarization batch 857/1491
# Processing summarization batch 858/1491
# Processing summarization batch 859/1491
# Processing summarization batch 860/1491
# Processing summarization batch 861/1491
# Processing summarization batch 862/1491
# Processing summarization batch 863/1491
# Processing summarization batch 864/1491
# Processing summarization batch 865/1491
# Processing summarization batch 866/1491
# Processing summarization batch 867/1491
# Processing summarization batch 868/1491
# Processing summarization batch 869/1491
# Processing summarization batch 870/1491
# Processing summarization batch 871/1491
# Processing summarization batch 872/1491
# Processing summarization batch 873/1491
# Processing summarization batch 874/1491
# Processing summarization batch 875/1491
# Processing summarization batch 876/1491
# Processing summarization batch 877/1491
# Processing summarization batch 878/1491
# Processing summarization batch 879/1491
# Processing summarization batch 880/1491
# Processing summarization batch 881/1491
# Processing summarization batch 882/1491
# Processing summarization batch 883/1491
# Processing summarization batch 884/1491
# Processing summarization batch 885/1491
# Processing summarization batch 886/1491
# Processing summarization batch 887/1491
# Processing summarization batch 888/1491
# Processing summarization batch 889/1491
# Processing summarization batch 890/1491
# Processing summarization batch 891/1491
# Processing summarization batch 892/1491
# Processing summarization batch 893/1491
# Processing summarization batch 894/1491
# Processing summarization batch 895/1491
# Processing summarization batch 896/1491
# Processing summarization batch 897/1491
# Processing summarization batch 898/1491
# Processing summarization batch 899/1491
# Processing summarization batch 900/1491
# Processing summarization batch 901/1491
# Processing summarization batch 902/1491
# Processing summarization batch 903/1491
# Processing summarization batch 904/1491
# Processing summarization batch 905/1491
# Processing summarization batch 906/1491
# Processing summarization batch 907/1491
# Processing summarization batch 908/1491
# Processing summarization batch 909/1491
# Processing summarization batch 910/1491
# Processing summarization batch 911/1491
# Processing summarization batch 912/1491
# Processing summarization batch 913/1491
# Processing summarization batch 914/1491
# Processing summarization batch 915/1491
# Processing summarization batch 916/1491
# Processing summarization batch 917/1491
# Processing summarization batch 918/1491
# Processing summarization batch 919/1491
# Processing summarization batch 920/1491
# Processing summarization batch 921/1491
# Processing summarization batch 922/1491
# Processing summarization batch 923/1491
# Processing summarization batch 924/1491
# Processing summarization batch 925/1491
# Processing summarization batch 926/1491
# Processing summarization batch 927/1491
# Processing summarization batch 928/1491
# Processing summarization batch 929/1491
# Processing summarization batch 930/1491
# Processing summarization batch 931/1491
# Processing summarization batch 932/1491
# Processing summarization batch 933/1491
# Processing summarization batch 934/1491
# Processing summarization batch 935/1491
# Processing summarization batch 936/1491
# Processing summarization batch 937/1491
# Processing summarization batch 938/1491
# Processing summarization batch 939/1491
# Processing summarization batch 940/1491
# Processing summarization batch 941/1491
# Processing summarization batch 942/1491
# Processing summarization batch 943/1491
# Processing summarization batch 944/1491
# Processing summarization batch 945/1491
# Processing summarization batch 946/1491
# Processing summarization batch 947/1491
# Processing summarization batch 948/1491
# Processing summarization batch 949/1491
# Processing summarization batch 950/1491
# Processing summarization batch 951/1491
# Processing summarization batch 952/1491
# Processing summarization batch 953/1491
# Processing summarization batch 954/1491
# Processing summarization batch 955/1491
# Processing summarization batch 956/1491
# Processing summarization batch 957/1491
# Processing summarization batch 958/1491
# Processing summarization batch 959/1491
# Processing summarization batch 960/1491
# Processing summarization batch 961/1491
# Processing summarization batch 962/1491
# Processing summarization batch 963/1491
# Processing summarization batch 964/1491
# Processing summarization batch 965/1491
# Processing summarization batch 966/1491
# Processing summarization batch 967/1491
# Processing summarization batch 968/1491
# Processing summarization batch 969/1491
# Processing summarization batch 970/1491
# Processing summarization batch 971/1491
# Processing summarization batch 972/1491
# Processing summarization batch 973/1491
# Processing summarization batch 974/1491
# Processing summarization batch 975/1491
# Processing summarization batch 976/1491
# Processing summarization batch 977/1491
# Processing summarization batch 978/1491
# Processing summarization batch 979/1491
# Processing summarization batch 980/1491
# Processing summarization batch 981/1491
# Processing summarization batch 982/1491
# Processing summarization batch 983/1491
# Processing summarization batch 984/1491
# Processing summarization batch 985/1491
# Processing summarization batch 986/1491
# Processing summarization batch 987/1491
# Processing summarization batch 988/1491
# Processing summarization batch 989/1491
# Processing summarization batch 990/1491
# Processing summarization batch 991/1491
# Processing summarization batch 992/1491
# Processing summarization batch 993/1491
# Processing summarization batch 994/1491
# Processing summarization batch 995/1491
# Processing summarization batch 996/1491
# Processing summarization batch 997/1491
# Processing summarization batch 998/1491
# Processing summarization batch 999/1491
# Processing summarization batch 1000/1491
# Processing summarization batch 1001/1491
# Processing summarization batch 1002/1491
# Processing summarization batch 1003/1491
# Processing summarization batch 1004/1491
# Processing summarization batch 1005/1491
# Processing summarization batch 1006/1491
# Processing summarization batch 1007/1491
# Processing summarization batch 1008/1491
# Processing summarization batch 1009/1491
# Processing summarization batch 1010/1491
# Processing summarization batch 1011/1491
# Processing summarization batch 1012/1491
# Processing summarization batch 1013/1491
# Processing summarization batch 1014/1491
# Processing summarization batch 1015/1491
# Processing summarization batch 1016/1491
# Processing summarization batch 1017/1491
# Processing summarization batch 1018/1491
# Processing summarization batch 1019/1491
# Processing summarization batch 1020/1491
# Processing summarization batch 1021/1491
# Processing summarization batch 1022/1491
# Processing summarization batch 1023/1491
# Processing summarization batch 1024/1491
# Processing summarization batch 1025/1491
# Processing summarization batch 1026/1491
# Processing summarization batch 1027/1491
# Processing summarization batch 1028/1491
# Processing summarization batch 1029/1491
# Processing summarization batch 1030/1491
# Processing summarization batch 1031/1491
# Processing summarization batch 1032/1491
# Processing summarization batch 1033/1491
# Processing summarization batch 1034/1491
# Processing summarization batch 1035/1491
# Processing summarization batch 1036/1491
# Processing summarization batch 1037/1491
# Processing summarization batch 1038/1491
# Processing summarization batch 1039/1491
# Processing summarization batch 1040/1491
# Processing summarization batch 1041/1491
# Processing summarization batch 1042/1491
# Processing summarization batch 1043/1491
# Processing summarization batch 1044/1491
# Processing summarization batch 1045/1491
# Processing summarization batch 1046/1491
# Processing summarization batch 1047/1491
# Processing summarization batch 1048/1491
# Processing summarization batch 1049/1491
# Processing summarization batch 1050/1491
# Processing summarization batch 1051/1491
# Processing summarization batch 1052/1491
# Processing summarization batch 1053/1491
# Processing summarization batch 1054/1491
# Processing summarization batch 1055/1491
# Processing summarization batch 1056/1491
# Processing summarization batch 1057/1491
# Processing summarization batch 1058/1491
# Processing summarization batch 1059/1491
# Processing summarization batch 1060/1491
# Processing summarization batch 1061/1491
# Processing summarization batch 1062/1491
# Processing summarization batch 1063/1491
# Processing summarization batch 1064/1491
# Processing summarization batch 1065/1491
# Processing summarization batch 1066/1491
# Processing summarization batch 1067/1491
# Processing summarization batch 1068/1491
# Processing summarization batch 1069/1491
# Processing summarization batch 1070/1491
# Processing summarization batch 1071/1491
# Processing summarization batch 1072/1491
# Processing summarization batch 1073/1491
# Processing summarization batch 1074/1491
# Processing summarization batch 1075/1491
# Processing summarization batch 1076/1491
# Processing summarization batch 1077/1491
# Processing summarization batch 1078/1491
# Processing summarization batch 1079/1491
# Processing summarization batch 1080/1491
# Processing summarization batch 1081/1491
# Processing summarization batch 1082/1491
# Processing summarization batch 1083/1491
# Processing summarization batch 1084/1491
# Processing summarization batch 1085/1491
# Processing summarization batch 1086/1491
# Processing summarization batch 1087/1491
# Processing summarization batch 1088/1491
# Processing summarization batch 1089/1491
# Processing summarization batch 1090/1491
# Processing summarization batch 1091/1491
# Processing summarization batch 1092/1491
# Processing summarization batch 1093/1491
# Processing summarization batch 1094/1491
# Processing summarization batch 1095/1491
# Processing summarization batch 1096/1491
# Processing summarization batch 1097/1491
# Processing summarization batch 1098/1491
# Processing summarization batch 1099/1491
# Processing summarization batch 1100/1491
# Processing summarization batch 1101/1491
# Processing summarization batch 1102/1491
# Processing summarization batch 1103/1491
# Processing summarization batch 1104/1491
# Processing summarization batch 1105/1491
# Processing summarization batch 1106/1491
# Processing summarization batch 1107/1491
# Processing summarization batch 1108/1491
# Processing summarization batch 1109/1491
# Processing summarization batch 1110/1491
# Processing summarization batch 1111/1491
# Processing summarization batch 1112/1491
# Processing summarization batch 1113/1491
# Processing summarization batch 1114/1491
# Processing summarization batch 1115/1491
# Processing summarization batch 1116/1491
# Processing summarization batch 1117/1491
# Processing summarization batch 1118/1491
# Processing summarization batch 1119/1491
# Processing summarization batch 1120/1491
# Processing summarization batch 1121/1491
# Processing summarization batch 1122/1491
# Processing summarization batch 1123/1491
# Processing summarization batch 1124/1491
# Processing summarization batch 1125/1491
# Processing summarization batch 1126/1491
# Processing summarization batch 1127/1491
# Processing summarization batch 1128/1491
# Processing summarization batch 1129/1491
# Processing summarization batch 1130/1491
# Processing summarization batch 1131/1491
# Processing summarization batch 1132/1491
# Processing summarization batch 1133/1491
# Processing summarization batch 1134/1491
# Processing summarization batch 1135/1491
# Processing summarization batch 1136/1491
# Processing summarization batch 1137/1491
# Processing summarization batch 1138/1491
# Processing summarization batch 1139/1491
# Processing summarization batch 1140/1491
# Processing summarization batch 1141/1491
# Processing summarization batch 1142/1491
# Processing summarization batch 1143/1491
# Processing summarization batch 1144/1491
# Processing summarization batch 1145/1491
# Processing summarization batch 1146/1491
# Processing summarization batch 1147/1491
# Processing summarization batch 1148/1491
# Processing summarization batch 1149/1491
# Processing summarization batch 1150/1491
# Processing summarization batch 1151/1491
# Processing summarization batch 1152/1491
# Processing summarization batch 1153/1491
# Processing summarization batch 1154/1491
# Processing summarization batch 1155/1491
# Processing summarization batch 1156/1491
# Processing summarization batch 1157/1491
# Processing summarization batch 1158/1491
# Processing summarization batch 1159/1491
# Processing summarization batch 1160/1491
# Processing summarization batch 1161/1491
# Processing summarization batch 1162/1491
# Processing summarization batch 1163/1491
# Processing summarization batch 1164/1491
# Processing summarization batch 1165/1491
# Processing summarization batch 1166/1491
# Processing summarization batch 1167/1491
# Processing summarization batch 1168/1491
# Processing summarization batch 1169/1491
# Processing summarization batch 1170/1491
# Processing summarization batch 1171/1491
# Processing summarization batch 1172/1491
# Processing summarization batch 1173/1491
# Processing summarization batch 1174/1491
# Processing summarization batch 1175/1491
# Processing summarization batch 1176/1491
# Processing summarization batch 1177/1491
# Processing summarization batch 1178/1491
# Processing summarization batch 1179/1491
# Processing summarization batch 1180/1491
# Processing summarization batch 1181/1491
# Processing summarization batch 1182/1491
# Processing summarization batch 1183/1491
# Processing summarization batch 1184/1491
# Processing summarization batch 1185/1491
# Processing summarization batch 1186/1491
# Processing summarization batch 1187/1491
# Processing summarization batch 1188/1491
# Processing summarization batch 1189/1491
# Processing summarization batch 1190/1491
# Processing summarization batch 1191/1491
# Processing summarization batch 1192/1491
# Processing summarization batch 1193/1491
# Processing summarization batch 1194/1491
# Processing summarization batch 1195/1491
# Processing summarization batch 1196/1491
# Processing summarization batch 1197/1491
# Processing summarization batch 1198/1491
# Processing summarization batch 1199/1491
# Processing summarization batch 1200/1491
# Processing summarization batch 1201/1491
# Processing summarization batch 1202/1491
# Processing summarization batch 1203/1491
# Processing summarization batch 1204/1491
# Processing summarization batch 1205/1491
# Processing summarization batch 1206/1491
# Processing summarization batch 1207/1491
# Processing summarization batch 1208/1491
# Processing summarization batch 1209/1491
# Processing summarization batch 1210/1491
# Processing summarization batch 1211/1491
# Processing summarization batch 1212/1491
# Processing summarization batch 1213/1491
# Processing summarization batch 1214/1491
# Processing summarization batch 1215/1491
# Processing summarization batch 1216/1491
# Processing summarization batch 1217/1491
# Processing summarization batch 1218/1491
# Processing summarization batch 1219/1491
# Processing summarization batch 1220/1491
# Processing summarization batch 1221/1491
# Processing summarization batch 1222/1491
# Processing summarization batch 1223/1491
# Processing summarization batch 1224/1491
# Processing summarization batch 1225/1491
# Processing summarization batch 1226/1491
# Processing summarization batch 1227/1491
# Processing summarization batch 1228/1491
# Processing summarization batch 1229/1491
# Processing summarization batch 1230/1491
# Processing summarization batch 1231/1491
# Processing summarization batch 1232/1491
# Processing summarization batch 1233/1491
# Processing summarization batch 1234/1491
# Processing summarization batch 1235/1491
# Processing summarization batch 1236/1491
# Processing summarization batch 1237/1491
# Processing summarization batch 1238/1491
# Processing summarization batch 1239/1491
# Processing summarization batch 1240/1491
# Processing summarization batch 1241/1491
# Processing summarization batch 1242/1491
# Processing summarization batch 1243/1491
# Processing summarization batch 1244/1491
# Processing summarization batch 1245/1491
# Processing summarization batch 1246/1491
# Processing summarization batch 1247/1491
# Processing summarization batch 1248/1491
# Processing summarization batch 1249/1491
# Processing summarization batch 1250/1491
# Processing summarization batch 1251/1491
# Processing summarization batch 1252/1491
# Processing summarization batch 1253/1491
# Processing summarization batch 1254/1491
# Processing summarization batch 1255/1491
# Processing summarization batch 1256/1491
# Processing summarization batch 1257/1491
# Processing summarization batch 1258/1491
# Processing summarization batch 1259/1491
# Processing summarization batch 1260/1491
# Processing summarization batch 1261/1491
# Processing summarization batch 1262/1491
# Processing summarization batch 1263/1491
# Processing summarization batch 1264/1491
# Processing summarization batch 1265/1491
# Processing summarization batch 1266/1491
# Processing summarization batch 1267/1491
# Processing summarization batch 1268/1491
# Processing summarization batch 1269/1491
# Processing summarization batch 1270/1491
# Processing summarization batch 1271/1491
# Processing summarization batch 1272/1491
# Processing summarization batch 1273/1491
# Processing summarization batch 1274/1491
# Processing summarization batch 1275/1491
# Processing summarization batch 1276/1491
# Processing summarization batch 1277/1491
# Processing summarization batch 1278/1491
# Processing summarization batch 1279/1491
# Processing summarization batch 1280/1491
# Processing summarization batch 1281/1491
# Processing summarization batch 1282/1491
# Processing summarization batch 1283/1491
# Processing summarization batch 1284/1491
# Processing summarization batch 1285/1491
# Processing summarization batch 1286/1491
# Processing summarization batch 1287/1491
# Processing summarization batch 1288/1491
# Processing summarization batch 1289/1491
# Processing summarization batch 1290/1491
# Processing summarization batch 1291/1491
# Processing summarization batch 1292/1491
# Processing summarization batch 1293/1491
# Processing summarization batch 1294/1491
# Processing summarization batch 1295/1491
# Processing summarization batch 1296/1491
# Processing summarization batch 1297/1491
# Processing summarization batch 1298/1491
# Processing summarization batch 1299/1491
# Processing summarization batch 1300/1491
# Processing summarization batch 1301/1491
# Processing summarization batch 1302/1491
# Processing summarization batch 1303/1491
# Processing summarization batch 1304/1491
# Processing summarization batch 1305/1491
# Processing summarization batch 1306/1491
# Processing summarization batch 1307/1491
# Processing summarization batch 1308/1491
# Processing summarization batch 1309/1491
# Processing summarization batch 1310/1491
# Processing summarization batch 1311/1491
# Processing summarization batch 1312/1491
# Processing summarization batch 1313/1491
# Processing summarization batch 1314/1491
# Processing summarization batch 1315/1491
# Processing summarization batch 1316/1491
# Processing summarization batch 1317/1491
# Processing summarization batch 1318/1491
# Processing summarization batch 1319/1491
# Processing summarization batch 1320/1491
# Processing summarization batch 1321/1491
# Processing summarization batch 1322/1491
# Processing summarization batch 1323/1491
# Processing summarization batch 1324/1491
# Processing summarization batch 1325/1491
# Processing summarization batch 1326/1491
# Processing summarization batch 1327/1491
# Processing summarization batch 1328/1491
# Processing summarization batch 1329/1491
# Processing summarization batch 1330/1491
# Processing summarization batch 1331/1491
# Processing summarization batch 1332/1491
# Processing summarization batch 1333/1491
# Processing summarization batch 1334/1491
# Processing summarization batch 1335/1491
# Processing summarization batch 1336/1491
# Processing summarization batch 1337/1491
# Processing summarization batch 1338/1491
# Processing summarization batch 1339/1491
# Processing summarization batch 1340/1491
# Processing summarization batch 1341/1491
# Processing summarization batch 1342/1491
# Processing summarization batch 1343/1491
# Processing summarization batch 1344/1491
# Processing summarization batch 1345/1491
# Processing summarization batch 1346/1491
# Processing summarization batch 1347/1491
# Processing summarization batch 1348/1491
# Processing summarization batch 1349/1491
# Processing summarization batch 1350/1491
# Processing summarization batch 1351/1491
# Processing summarization batch 1352/1491
# Processing summarization batch 1353/1491
# Processing summarization batch 1354/1491
# Processing summarization batch 1355/1491
# Processing summarization batch 1356/1491
# Processing summarization batch 1357/1491
# Processing summarization batch 1358/1491
# Processing summarization batch 1359/1491
# Processing summarization batch 1360/1491
# Processing summarization batch 1361/1491
# Processing summarization batch 1362/1491
# Processing summarization batch 1363/1491
# Processing summarization batch 1364/1491
# Processing summarization batch 1365/1491
# Processing summarization batch 1366/1491
# Processing summarization batch 1367/1491
# Processing summarization batch 1368/1491
# Processing summarization batch 1369/1491
# Processing summarization batch 1370/1491
# Processing summarization batch 1371/1491
# Processing summarization batch 1372/1491
# Processing summarization batch 1373/1491
# Processing summarization batch 1374/1491
# Processing summarization batch 1375/1491
# Processing summarization batch 1376/1491
# Processing summarization batch 1377/1491
# Processing summarization batch 1378/1491
# Processing summarization batch 1379/1491
# Processing summarization batch 1380/1491
# Processing summarization batch 1381/1491
# Processing summarization batch 1382/1491
# Processing summarization batch 1383/1491
# Processing summarization batch 1384/1491
# Processing summarization batch 1385/1491
# Processing summarization batch 1386/1491
# Processing summarization batch 1387/1491
# Processing summarization batch 1388/1491
# Processing summarization batch 1389/1491
# Processing summarization batch 1390/1491
# Processing summarization batch 1391/1491
# Processing summarization batch 1392/1491
# Processing summarization batch 1393/1491
# Processing summarization batch 1394/1491
# Processing summarization batch 1395/1491
# Processing summarization batch 1396/1491
# Processing summarization batch 1397/1491
# Processing summarization batch 1398/1491
# Processing summarization batch 1399/1491
# Processing summarization batch 1400/1491
# Processing summarization batch 1401/1491
# Processing summarization batch 1402/1491
# Processing summarization batch 1403/1491
# Processing summarization batch 1404/1491
# Processing summarization batch 1405/1491
# Processing summarization batch 1406/1491
# Processing summarization batch 1407/1491
# Processing summarization batch 1408/1491
# Processing summarization batch 1409/1491
# Processing summarization batch 1410/1491
# Processing summarization batch 1411/1491
# Processing summarization batch 1412/1491
# Processing summarization batch 1413/1491
# Processing summarization batch 1414/1491
# Processing summarization batch 1415/1491
# Processing summarization batch 1416/1491
# Processing summarization batch 1417/1491
# Processing summarization batch 1418/1491
# Processing summarization batch 1419/1491
# Processing summarization batch 1420/1491
# Processing summarization batch 1421/1491
# Processing summarization batch 1422/1491
# Processing summarization batch 1423/1491
# Processing summarization batch 1424/1491
# Processing summarization batch 1425/1491
# Processing summarization batch 1426/1491
# Processing summarization batch 1427/1491
# Processing summarization batch 1428/1491
# Processing summarization batch 1429/1491
# Processing summarization batch 1430/1491
# Processing summarization batch 1431/1491
# Processing summarization batch 1432/1491
# Processing summarization batch 1433/1491
# Processing summarization batch 1434/1491
# Processing summarization batch 1435/1491
# Processing summarization batch 1436/1491
# Processing summarization batch 1437/1491
# Processing summarization batch 1438/1491
# Processing summarization batch 1439/1491
# Processing summarization batch 1440/1491
# Processing summarization batch 1441/1491
# Processing summarization batch 1442/1491
# Processing summarization batch 1443/1491
# Processing summarization batch 1444/1491
# Processing summarization batch 1445/1491
# Processing summarization batch 1446/1491
# Processing summarization batch 1447/1491
# Processing summarization batch 1448/1491
# Processing summarization batch 1449/1491
# Processing summarization batch 1450/1491
# Processing summarization batch 1451/1491
# Processing summarization batch 1452/1491
# Processing summarization batch 1453/1491
# Processing summarization batch 1454/1491
# Processing summarization batch 1455/1491
# Processing summarization batch 1456/1491
# Processing summarization batch 1457/1491
# Processing summarization batch 1458/1491
# Processing summarization batch 1459/1491
# Processing summarization batch 1460/1491
# Processing summarization batch 1461/1491
# Processing summarization batch 1462/1491
# Processing summarization batch 1463/1491
# Processing summarization batch 1464/1491
# Processing summarization batch 1465/1491
# Processing summarization batch 1466/1491
# Processing summarization batch 1467/1491
# Processing summarization batch 1468/1491
# Processing summarization batch 1469/1491
# Processing summarization batch 1470/1491
# Processing summarization batch 1471/1491
# Processing summarization batch 1472/1491
# Processing summarization batch 1473/1491
# Processing summarization batch 1474/1491
# Processing summarization batch 1475/1491
# Processing summarization batch 1476/1491
# Processing summarization batch 1477/1491
# Processing summarization batch 1478/1491
# Processing summarization batch 1479/1491
# Processing summarization batch 1480/1491
# Processing summarization batch 1481/1491
# Processing summarization batch 1482/1491
# Processing summarization batch 1483/1491
# Processing summarization batch 1484/1491
# Processing summarization batch 1485/1491
# Processing summarization batch 1486/1491
# Processing summarization batch 1487/1491
# Processing summarization batch 1488/1491
# Processing summarization batch 1489/1491
# Processing summarization batch 1490/1491
# Processing summarization batch 1491/1491
# Summarization completed in 0.08 seconds

# %%
# Analyze summarized text lengths
df['summarized_word_count'] = df['summarized_text'].apply(count_words)
print(f"\nSummarized text statistics:")
print(f"Mean words: {df['summarized_word_count'].mean():.1f}")
print(f"Median words: {df['summarized_word_count'].median():.1f}")
print(f"Max words: {df['summarized_word_count'].max()}")
# Out:
# Summarized text statistics:
# Mean words: 62.7
# Median words: 58.0
# Max words: 276

# %%
# Encode target labels
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['queue'])
num_labels = len(label_encoder.classes_)
print(f"\nNumber of classes: {num_labels}")
print(f"Classes: {list(label_encoder.classes_)}")
# Out:
# Number of classes: 5
# Classes: ['Billing Support', 'Customer Service', 'Product Support', 'Sales & HR', 'Technical Support']

# %%
# Select required columns
df_final = df[['summarized_text', 'label']].copy()

# Split into train and validation sets
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df_final['summarized_text'],
    df_final['label'],
    test_size=0.2,
    stratify=df_final['label'],
    random_state=42
)
print(f"\nDataset split:")
print(f"Training samples: {len(train_texts)}")
print(f"Validation samples: {len(val_texts)}")
# Out:
# Dataset split:
# Training samples: 9538
# Validation samples: 2385
